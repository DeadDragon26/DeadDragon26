# %% [markdown]
# <a href="https://colab.research.google.com/github/DeadDragon26/DeadDragon26/blob/main/Kmeans_elbow_curve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np

data=pd.read_csv("/content/shopping_trends.csv")
x = data[["Age", "Purchase Amount (USD)"]]

data = pd.get_dummies(data, columns=['Gender'])
x = data[["Age", "Purchase Amount (USD)", "Gender_Female", "Gender_Male"]]

inertias = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(x)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,11), inertias, marker='o')
plt.title('Elbow curve')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
